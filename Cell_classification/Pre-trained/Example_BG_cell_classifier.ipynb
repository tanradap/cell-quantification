# %% [markdown]
# ### Occipital classifier on novel slides

# %%
# load important libraries
import sys
sys.path.insert(0,
                '/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/Cell_classification/')
from base import *
from constants import *
import joblib

# %% [markdown]
# Load cortical classifier

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/Cell_classification/Models/"
filename = "bg_cell_classifier.sav"
model = joblib.load(path+filename)

# %%
model.best_parameters
# Out:
# {0: (0.4592835374462488,
#   0.6815173626938333,
#   0.6891846826044234,
#   0.7271929824561404),
#  1: (0.48042408021969285, 0.8543324993612236, 0.8301907662241488, 0.89),
#  2: (0.5122155925759821,
#   0.917856339157616,
#   0.9174491900312752,
#   0.9206913339824732),
#  3: (0.2164000689682492,
#   0.8331716197778333,
#   0.8025224539600778,
#   0.87512077294686)}

# %%
model.f_importance.head()
# Out:
#                     features  importance
# 1         Nucleus: Area µm^2    0.123232
# 2         Nucleus: Length µm    0.110194
# 5   Nucleus: Max diameter µm    0.100658
# 6   Nucleus: Min diameter µm    0.077623
# 11     Cell: Max diameter µm    0.072434

# %% [markdown]
# Import files to make predictions on

# %%
# Data file 
with open("C:/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/Metadata/bg_stardist.txt") as f: 
    mylist= f.read().splitlines()
    
print("Read in:",len(mylist)," files")

# NB files 
nb_mylist = [i[0:6]+'_all_neighbours.csv' for i in  mylist]

# # Hema files 
# hema_mylist = [i[0:6]+'_hema.csv' for i in  mylist]

print("Generated filename list for nb:", len(nb_mylist), "nb files")
print("Equal number of files?:", (len(mylist)==len(nb_mylist)))

# print("Generated filename list for hema:", len(hema_mylist), "hema files")
# print("Equal number of files?:", (len(mylist)==len(nb_mylist))==(len(mylist)==len(hema_mylist)))
# Out:
# Read in: 40  files
# Generated filename list for nb: 40 nb files
# Equal number of files?: True

# %% [markdown]
# 747286_all.txt' - missing

# %%
i
# Out:
# 2

# %%
mylist = mylist[3:]
nb_mylist = nb_mylist[3:]

# %% [markdown]
# Process new files to make predictions

# %%
n_total = len(mylist)
faulty_file = []
for i in range(0,n_total):
    
    # Read in unlabelled/unannotated file
    print("FILE", mylist[i], "Number: ", i+1,"/",n_total)
    print("---------------STEP1: DATA FILE-------------------")
    dat_file = mylist[i]
    
    dat_orig = pd.read_csv('C:/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/detection_stardist/'+dat_file,sep="\t")
    dat_orig.columns.values[5] = "Centroid_X"
    dat_orig.columns.values[6] = "Centroid_Y"
    dat_ = dat_orig[cell_extracted_features]
    dab_df = dat_orig[dab_features]
    dat = dat_.copy()
    dat.loc[:,'Class'] = dat.shape[0]*['Unlabelled']
    print("Read in data file:", dat_file)
    print("Data shape is:", dat.shape)
    print("----------------------------------------------------------------------------")
    
    # Importing NB cells
    print("---------------STEP2: NB FILE-------------------")
    nb_dat_file = nb_mylist[i]
    nb_dat_ = pd.read_csv('E:/number_of_neighbours/'+nb_dat_file,sep=",")
    nb_dat_ = nb_dat_.rename(columns={'X':'Centroid_X','Y':'Centroid_Y'})
    nb_dat = nb_dat_[nnb_extracted_features]
    
    print("Read in nb file:", nb_dat_file)
    print("nb_dat shape is:", nb_dat.shape)
    print("-----------------------------------------")
    
    ## Merge NB info to main data ***** From now on: Use 'combined'
    combined = dat.merge(nb_dat.drop_duplicates(),on=['Centroid_X','Centroid_Y'],how='inner',validate='1:1')
    print("Successfully combine nb cell counts to main data")
    print('Expected & Observed row matched?: ', dat.shape[0]==combined.shape[0])
    print('Expected & Observed columns matched?: ', (dat.shape[1]+nb_dat.shape[1]-2)==combined.shape[1])
    print("----------------------------------------------------------------------------")
    

    # Importing hema files 
    print("---------------STEP3: HEMA FILE-------------------")
    hema_dat = dat[['Centroid_X','Centroid_Y','Hematoxylin: Nucleus: Mean']]
    print("hema_dat shape is:", hema_dat.shape)
    print("----------------------------------------------------------------------------")
    
    ############################  Normalising hema files ############################ 
    print("---------------STEP4: HEMA NORM-------------------")
    
    # 1) Find cells need removing 
    hema_to_remove = find_hema_to_remove_slide(hema_dat)
    print("No. of cells with normalised Hema >1:",
          len(hema_to_remove),
            "from", len(hema_dat),"detected cells")

    # 2) Remove hema from the slides 
    retained, removed_, remove_log = remove_cell_hema_slide(combined,
                           hema_to_remove)
    
    print(dat_file,":",
           'To be removed = actually removed?',remove_log,
           ' &',removed_.shape[0],"cells removed")
    
    # label those cells we have removed as having Class = 'Excluded'
    removed = removed_.copy()
    removed.loc[:,'Class'] = ['Excluded']*removed.shape[0]

    print("----------------------------------------------------------------------------")

    ############################ Checking for NAs & Other bits  
    print("---------------STEP5: CHECKING NA & REGIONS-------------------")
    
    # 1) Selecting regions that are not doesnt matter (selected regions will be the 3 nuclei of interest)
    if (retained[retained['Name']!='Doesnt_matter'].shape[0] == 0): 
        faulty_file.append(retained['Image'][0])
        continue  
    
    retained2 = retained[retained['Name']!='Doesnt_matter']  # only has nuclei of interest
    retained_not_GM = retained[retained['Name']=='Doesnt_matter'] # BG regions NOT of interest
    

    # 2) Remove NA cells 
    retained3 = retained2.dropna()
    NA_proportion = retained2[retained2.isna().any(axis=1)]
    print("Shape of data, ready for prediction", retained3.shape)


    print("----------------------------------------------------------------------------")
 
    ############################ Prediction
    print("---------------STEP7: PREDICTIONS-------------------")
    
    # Create new variable for retained to add Class predictions to
    retained_final = retained3.copy()

    # Dropping extra info features 
    X_unlabelled = retained3.drop(columns=['Image',
                                           'Name',
                                           'Class',
                                           'Parent',
                                           'ROI',
                                           'Centroid_X',
                                           'Centroid_Y'])
    print('X_unlabelled shape: ', X_unlabelled.shape)

        
    # 1) Perform prediction on the novel slide
    model.predict(X_unlabelled)
    retained_final.loc[:,'Class'] = model.prediction
    print(retained_final['Class'].value_counts())
    
    print("----------------------------------------------------------------------------")
    ############################ Extracting data out  ############################ 
    print("---------------STEP8: DATA EXTRACTION & EXPORT-------------------")

    # 1) Combining predicted cells & excluded cells (prior to prediction)
    output_slide = pd.concat([removed, # from hema
                              retained_not_GM, # non GM 
                              NA_proportion, # GM with NA 
                              retained_final]) # predicted GM portion
    
    # 2) Add DAB information 
    output_slide_dab = output_slide.merge(dab_df,on=['Centroid_X','Centroid_Y'])
    
    # 2) Checking input data == output data 
    print("Input data == output data?:", combined.shape[0]==output_slide_dab.shape[0])

    # 3) Checking if there are NA values in predicted portion after combining data 
    pred_complete=output_slide_dab[output_slide_dab['Class']!='Unlabelled'].isna().sum().sum()
    print("No NAN values in predicted portion?: ", 0==pred_complete)
    
    # 4) Exporting relevant information 
    path = 'C:/Users/mokur/OneDrive/Desktop/Digital_path/Cell_pipeline/Predictions/BG/' + output_slide_dab.iloc[0,0]+'_predictions.txt'
    output_slide_dab.to_csv(path, sep='\t',index=False)
    print("Exported prediction of : ",dat_file)
    print("----------------------------------------------------------------------------")

print("**********ALL DONE! YAY, no error!***********")
# Out:
# FILE 747815_all.txt Number:  1 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747815_all.txt
# Data shape is: (847544, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747815_all_neighbours.csv
# nb_dat shape is: (847544, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (847544, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8475 from 847544 detected cells
# 747815_all.txt : To be removed = actually removed? True  & 8475 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (198314, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (198314, 44)
# Others       70315
# Oligo        65565
# Neuron       28377
# Ambiguous    17128
# Astro        16929
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747815_all.txt
# ----------------------------------------------------------------------------
# FILE 747816_all.txt Number:  2 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747816_all.txt
# Data shape is: (740494, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747816_all_neighbours.csv
# nb_dat shape is: (740494, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (740494, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7403 from 740494 detected cells
# 747816_all.txt : To be removed = actually removed? True  & 7403 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (142821, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (142821, 44)
# Others       57840
# Oligo        39961
# Astro        17566
# Neuron       13772
# Ambiguous    13682
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747816_all.txt
# ----------------------------------------------------------------------------
# FILE 747868_all.txt Number:  3 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747868_all.txt
# Data shape is: (752197, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747868_all_neighbours.csv
# nb_dat shape is: (752197, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (752197, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7522 from 752197 detected cells
# 747868_all.txt : To be removed = actually removed? True  & 7522 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (138862, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (138862, 44)
# Others       56435
# Oligo        37468
# Astro        17644
# Neuron       14192
# Ambiguous    13123
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747868_all.txt
# ----------------------------------------------------------------------------
# FILE 722594_all.txt Number:  4 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 722594_all.txt
# Data shape is: (1006408, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 722594_all_neighbours.csv
# nb_dat shape is: (1006408, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (1006408, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 10049 from 1006408 detected cells
# 722594_all.txt : To be removed = actually removed? True  & 10049 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (265839, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (265839, 44)
# Others       136647
# Oligo         67891
# Neuron        24675
# Ambiguous     21132
# Astro         15494
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  722594_all.txt
# ----------------------------------------------------------------------------
# FILE 747131_all.txt Number:  5 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747131_all.txt
# Data shape is: (767096, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747131_all_neighbours.csv
# nb_dat shape is: (767096, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (767096, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7664 from 767096 detected cells
# 747131_all.txt : To be removed = actually removed? True  & 7664 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (164413, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (164413, 44)
# Oligo        67691
# Others       55091
# Astro        15948
# Neuron       13951
# Ambiguous    11732
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747131_all.txt
# ----------------------------------------------------------------------------
# FILE 721708_all.txt Number:  6 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721708_all.txt
# Data shape is: (746312, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 721708_all_neighbours.csv
# nb_dat shape is: (746312, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (746312, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7455 from 746312 detected cells
# 721708_all.txt : To be removed = actually removed? True  & 7455 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (182988, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (182988, 44)
# Oligo        83627
# Others       48490
# Astro        20494
# Neuron       18255
# Ambiguous    12122
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  721708_all.txt
# ----------------------------------------------------------------------------
# FILE 747818_all.txt Number:  7 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747818_all.txt
# Data shape is: (780590, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747818_all_neighbours.csv
# nb_dat shape is: (780590, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (780590, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7791 from 780590 detected cells
# 747818_all.txt : To be removed = actually removed? True  & 7791 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (125856, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (125856, 44)
# Oligo        43469
# Others       39688
# Neuron       18972
# Astro        13299
# Ambiguous    10428
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747818_all.txt
# ----------------------------------------------------------------------------
# FILE 721866_all.txt Number:  8 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 721866_all.txt
# Data shape is: (758788, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 721866_all_neighbours.csv
# nb_dat shape is: (758788, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (758788, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7577 from 758788 detected cells
# 721866_all.txt : To be removed = actually removed? True  & 7577 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (141378, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (141378, 44)
# Oligo        52969
# Others       40245
# Astro        19990
# Neuron       17686
# Ambiguous    10488
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  721866_all.txt
# ----------------------------------------------------------------------------
# FILE 747870_all.txt Number:  9 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747870_all.txt
# Data shape is: (663412, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747870_all_neighbours.csv
# nb_dat shape is: (663412, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (663412, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6623 from 663412 detected cells
# 747870_all.txt : To be removed = actually removed? True  & 6623 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (186619, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (186619, 44)
# Oligo        73880
# Others       56361
# Neuron       27424
# Ambiguous    19910
# Astro         9044
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747870_all.txt
# ----------------------------------------------------------------------------
# FILE 747820_all.txt Number:  10 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747820_all.txt
# Data shape is: (792783, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747820_all_neighbours.csv
# nb_dat shape is: (792783, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (792783, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7917 from 792783 detected cells
# 747820_all.txt : To be removed = actually removed? True  & 7917 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (197881, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (197881, 44)
# Oligo        73816
# Others       66969
# Astro        21751
# Neuron       21359
# Ambiguous    13986
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747820_all.txt
# ----------------------------------------------------------------------------
# FILE 747857_all.txt Number:  11 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747857_all.txt
# Data shape is: (787370, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747857_all_neighbours.csv
# nb_dat shape is: (787370, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (787370, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7853 from 787370 detected cells
# 747857_all.txt : To be removed = actually removed? True  & 7853 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (146210, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (146210, 44)
# Oligo        55676
# Others       45039
# Neuron       20071
# Astro        13317
# Ambiguous    12107
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747857_all.txt
# ----------------------------------------------------------------------------
# FILE 755497_all.txt Number:  12 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 755497_all.txt
# Data shape is: (409910, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 755497_all_neighbours.csv
# nb_dat shape is: (409910, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (409910, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 4099 from 409910 detected cells
# 755497_all.txt : To be removed = actually removed? True  & 4099 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (138083, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (138083, 44)
# Oligo        57694
# Others       42836
# Neuron       16540
# Ambiguous    10531
# Astro        10482
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  755497_all.txt
# ----------------------------------------------------------------------------
# FILE 755511_all.txt Number:  13 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 755511_all.txt
# Data shape is: (620694, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 755511_all_neighbours.csv
# nb_dat shape is: (620694, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (620694, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6204 from 620694 detected cells
# 755511_all.txt : To be removed = actually removed? True  & 6204 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (108928, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (108928, 44)
# Oligo        39438
# Others       34299
# Neuron       14115
# Astro        12628
# Ambiguous     8448
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  755511_all.txt
# ----------------------------------------------------------------------------
# FILE 747309_all.txt Number:  14 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747309_all.txt
# Data shape is: (700326, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747309_all_neighbours.csv
# nb_dat shape is: (700326, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (700326, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6991 from 700326 detected cells
# 747309_all.txt : To be removed = actually removed? True  & 6991 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (129039, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (129039, 44)
# Others       45772
# Oligo        41048
# Neuron       19266
# Astro        12222
# Ambiguous    10731
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747309_all.txt
# ----------------------------------------------------------------------------
# FILE 747293_all.txt Number:  15 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747293_all.txt
# Data shape is: (786354, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747293_all_neighbours.csv
# nb_dat shape is: (786354, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (786354, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7847 from 786354 detected cells
# 747293_all.txt : To be removed = actually removed? True  & 7847 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (149356, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (149356, 44)
# Oligo        57526
# Others       52634
# Neuron       14524
# Astro        13458
# Ambiguous    11214
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747293_all.txt
# ----------------------------------------------------------------------------
# FILE 703476_all.txt Number:  16 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703476_all.txt
# Data shape is: (816170, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 703476_all_neighbours.csv
# nb_dat shape is: (816170, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (816170, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8146 from 816170 detected cells
# 703476_all.txt : To be removed = actually removed? True  & 8146 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# FILE 703488_all.txt Number:  17 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703488_all.txt
# Data shape is: (839552, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 703488_all_neighbours.csv
# nb_dat shape is: (839552, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (839552, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8374 from 839552 detected cells
# 703488_all.txt : To be removed = actually removed? True  & 8374 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# FILE 747821_all.txt Number:  18 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747821_all.txt
# Data shape is: (831951, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747821_all_neighbours.csv
# nb_dat shape is: (831951, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (831951, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8317 from 831951 detected cells
# 747821_all.txt : To be removed = actually removed? True  & 8317 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (171933, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (171933, 44)
# Others       63256
# Oligo        55789
# Astro        19709
# Neuron       17964
# Ambiguous    15215
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747821_all.txt
# ----------------------------------------------------------------------------
# FILE 703952_all.txt Number:  19 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703952_all.txt
# Data shape is: (700113, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 703952_all_neighbours.csv
# nb_dat shape is: (700113, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (700113, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6974 from 700113 detected cells
# 703952_all.txt : To be removed = actually removed? True  & 6974 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# FILE 747295_all.txt Number:  20 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747295_all.txt
# Data shape is: (652818, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747295_all_neighbours.csv
# nb_dat shape is: (652818, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (652818, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6513 from 652818 detected cells
# 747295_all.txt : To be removed = actually removed? True  & 6513 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (137250, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (137250, 44)
# Others       57394
# Oligo        36853
# Neuron       19089
# Ambiguous    12308
# Astro        11606
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747295_all.txt
# ----------------------------------------------------------------------------
# FILE 747296_all.txt Number:  21 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747296_all.txt
# Data shape is: (678253, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747296_all_neighbours.csv
# nb_dat shape is: (678253, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (678253, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6767 from 678253 detected cells
# 747296_all.txt : To be removed = actually removed? True  & 6767 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (146231, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (146231, 44)
# Oligo        47273
# Others       44288
# Astro        22556
# Neuron       21044
# Ambiguous    11070
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747296_all.txt
# ----------------------------------------------------------------------------
# FILE 747828_all.txt Number:  22 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747828_all.txt
# Data shape is: (609511, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747828_all_neighbours.csv
# nb_dat shape is: (609511, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (609511, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6092 from 609511 detected cells
# 747828_all.txt : To be removed = actually removed? True  & 6092 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (225231, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (225231, 44)
# Oligo        98451
# Others       59146
# Neuron       26844
# Astro        25510
# Ambiguous    15280
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747828_all.txt
# ----------------------------------------------------------------------------
# FILE 747297_all.txt Number:  23 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747297_all.txt
# Data shape is: (735776, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747297_all_neighbours.csv
# nb_dat shape is: (735776, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (735776, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7354 from 735776 detected cells
# 747297_all.txt : To be removed = actually removed? True  & 7354 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (179878, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (179878, 44)
# Oligo        64246
# Others       55304
# Neuron       26345
# Astro        22023
# Ambiguous    11960
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747297_all.txt
# ----------------------------------------------------------------------------
# FILE 747308_all.txt Number:  24 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747308_all.txt
# Data shape is: (450168, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747308_all_neighbours.csv
# nb_dat shape is: (450168, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (450168, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 4499 from 450168 detected cells
# 747308_all.txt : To be removed = actually removed? True  & 4499 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (175622, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (175622, 44)
# Oligo        63774
# Others       54550
# Astro        21756
# Neuron       21212
# Ambiguous    14330
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747308_all.txt
# ----------------------------------------------------------------------------
# FILE 747822_all.txt Number:  25 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747822_all.txt
# Data shape is: (789655, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747822_all_neighbours.csv
# nb_dat shape is: (789655, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (789655, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7890 from 789655 detected cells
# 747822_all.txt : To be removed = actually removed? True  & 7890 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (181271, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (181271, 44)
# Oligo        71005
# Others       54905
# Neuron       24151
# Astro        17181
# Ambiguous    14029
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747822_all.txt
# ----------------------------------------------------------------------------
# FILE 747299_all.txt Number:  26 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747299_all.txt
# Data shape is: (809585, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747299_all_neighbours.csv
# nb_dat shape is: (809585, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (809585, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8095 from 809585 detected cells
# 747299_all.txt : To be removed = actually removed? True  & 8095 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (178088, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (178088, 44)
# Oligo        67441
# Others       54148
# Neuron       24514
# Astro        18992
# Ambiguous    12993
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747299_all.txt
# ----------------------------------------------------------------------------
# FILE 747823_all.txt Number:  27 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747823_all.txt
# Data shape is: (761545, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747823_all_neighbours.csv
# nb_dat shape is: (761545, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (761545, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7603 from 761545 detected cells
# 747823_all.txt : To be removed = actually removed? True  & 7603 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (209910, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (209910, 44)
# Oligo        99713
# Others       53290
# Neuron       29644
# Ambiguous    14611
# Astro        12652
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747823_all.txt
# ----------------------------------------------------------------------------
# FILE 747301_all.txt Number:  28 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747301_all.txt
# Data shape is: (703594, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747301_all_neighbours.csv
# nb_dat shape is: (703594, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (703594, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7022 from 703594 detected cells
# 747301_all.txt : To be removed = actually removed? True  & 7022 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (145170, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (145170, 44)
# Oligo        54669
# Others       37718
# Neuron       23711
# Astro        18133
# Ambiguous    10939
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747301_all.txt
# ----------------------------------------------------------------------------
# FILE 747871_all.txt Number:  29 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747871_all.txt
# Data shape is: (877220, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747871_all_neighbours.csv
# nb_dat shape is: (877220, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (877220, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8758 from 877220 detected cells
# 747871_all.txt : To be removed = actually removed? True  & 8758 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (185254, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (185254, 44)
# Oligo        83129
# Others       46576
# Astro        21077
# Neuron       20728
# Ambiguous    13744
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747871_all.txt
# ----------------------------------------------------------------------------
# FILE 747303_all.txt Number:  30 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747303_all.txt
# Data shape is: (589171, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747303_all_neighbours.csv
# nb_dat shape is: (589171, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (589171, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 5892 from 589171 detected cells
# 747303_all.txt : To be removed = actually removed? True  & 5892 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (117946, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (117946, 44)
# Others       60893
# Astro        21237
# Oligo        17712
# Ambiguous    12325
# Neuron        5779
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747303_all.txt
# ----------------------------------------------------------------------------
# FILE 747872_all.txt Number:  31 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747872_all.txt
# Data shape is: (795898, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747872_all_neighbours.csv
# nb_dat shape is: (795898, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (795898, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7955 from 795898 detected cells
# 747872_all.txt : To be removed = actually removed? True  & 7955 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (175960, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (175960, 44)
# Oligo        71268
# Others       52752
# Astro        20825
# Neuron       18062
# Ambiguous    13053
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747872_all.txt
# ----------------------------------------------------------------------------
# FILE 747826_all.txt Number:  32 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747826_all.txt
# Data shape is: (767810, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747826_all_neighbours.csv
# nb_dat shape is: (767810, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (767810, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7649 from 767810 detected cells
# 747826_all.txt : To be removed = actually removed? True  & 7649 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (205210, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (205210, 44)
# Oligo        75992
# Others       67521
# Neuron       26885
# Astro        20639
# Ambiguous    14173
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747826_all.txt
# ----------------------------------------------------------------------------
# FILE 747827_all.txt Number:  33 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747827_all.txt
# Data shape is: (839332, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747827_all_neighbours.csv
# nb_dat shape is: (839332, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (839332, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 8372 from 839332 detected cells
# 747827_all.txt : To be removed = actually removed? True  & 8372 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (93328, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (93328, 44)
# Oligo        35063
# Others       28157
# Astro        12345
# Neuron       11151
# Ambiguous     6612
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747827_all.txt
# ----------------------------------------------------------------------------
# FILE 771775_all.txt Number:  34 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771775_all.txt
# Data shape is: (724957, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 771775_all_neighbours.csv
# nb_dat shape is: (724957, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  False
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (724957, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 7233 from 724957 detected cells
# 771775_all.txt : To be removed = actually removed? True  & 7233 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (209582, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (209582, 44)
# Oligo        97193
# Others       50737
# Neuron       25327
# Astro        22956
# Ambiguous    13369
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  771775_all.txt
# ----------------------------------------------------------------------------
# FILE 771885_all.txt Number:  35 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771885_all.txt
# Data shape is: (602155, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 771885_all_neighbours.csv
# nb_dat shape is: (602155, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (602155, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6019 from 602155 detected cells
# 771885_all.txt : To be removed = actually removed? True  & 6019 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (192273, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (192273, 44)
# Oligo        82619
# Others       50103
# Neuron       23355
# Astro        22394
# Ambiguous    13802
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  771885_all.txt
# ----------------------------------------------------------------------------
# FILE 772011_all.txt Number:  36 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772011_all.txt
# Data shape is: (901604, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 772011_all_neighbours.csv
# nb_dat shape is: (901604, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (901604, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 9011 from 901604 detected cells
# 772011_all.txt : To be removed = actually removed? True  & 9011 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (190748, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (190748, 44)
# Oligo        90021
# Others       49172
# Ambiguous    18195
# Astro        18033
# Neuron       15327
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  772011_all.txt
# ----------------------------------------------------------------------------
# FILE 771914_all.txt Number:  37 / 37
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771914_all.txt
# Data shape is: (651723, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 771914_all_neighbours.csv
# nb_dat shape is: (651723, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (651723, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6503 from 651723 detected cells
# 771914_all.txt : To be removed = actually removed? True  & 6503 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (135677, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (135677, 44)
# Others       47196
# Oligo        40840
# Neuron       21584
# Astro        15208
# Ambiguous    10849
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  771914_all.txt
# ----------------------------------------------------------------------------
# **********ALL DONE! YAY, no error!***********
