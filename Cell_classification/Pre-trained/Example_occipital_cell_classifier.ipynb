# %% [markdown]
# ### Occipital classifier on novel slides

# %%
# load important libraries
import sys
sys.path.insert(0,
                '/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/Cell_classification/')
from base import *
from constants import *
import joblib

# %% [markdown]
# Load cortical classifier

# %%
path = "/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/Cell_classification/Models/"
filename = "occipital_cell_classifier.sav"
model = joblib.load(path+filename)

# %%
model.pipeline
# Out:
# Pipeline(steps=[('normalizer', MinMaxScaler()),
#                 ('selector',
#                  RFE(estimator=RandomForestClassifier(random_state=42),
#                      n_features_to_select=28)),
#                 ('clf',
#                  BalancedRandomForestClassifier(class_weight='balanced',
#                                                 max_depth=15, max_features=0.4,
#                                                 max_samples=0.25,
#                                                 min_samples_leaf=4,
#                                                 min_samples_split=10,
#                                                 n_estimators=200,
#                                                 random_state=42))])

# %%
model.best_parameters
# Out:
# {0: (0.46755140108518506,
#   0.64622061572346,
#   0.5524263118410125,
#   0.809090909090909),
#  1: (0.35800301310120014,
#   0.8404223852097499,
#   0.8257465256800274,
#   0.8658687943262411),
#  2: (0.38978088189514104,
#   0.8427582788906303,
#   0.8476453077212108,
#   0.848989898989899),
#  3: (0.3327053512581415,
#   0.833597139312819,
#   0.8379277250873924,
#   0.8324248777078965)}

# %%
model.f_importance.head()
# Out:
#                    features  importance
# 1        Nucleus: Area µm^2    0.132467
# 4  Nucleus: Max diameter µm    0.124573
# 0     Detection probability    0.117742
# 2        Nucleus: Length µm    0.117511
# 5  Nucleus: Min diameter µm    0.079836

# %% [markdown]
# Import files to make predictions on

# %%
# Data file 
with open("C:/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/Metadata/occipital_stardist.txt") as f: 
    mylist= f.read().splitlines()
    
print("Read in:",len(mylist)," files")

# NB files 
nb_mylist = [i[0:6]+'_all_neighbours.csv' for i in  mylist]

# # Hema files 
# hema_mylist = [i[0:6]+'_hema.csv' for i in  mylist]

print("Generated filename list for nb:", len(nb_mylist), "nb files")
print("Equal number of files?:", (len(mylist)==len(nb_mylist)))

# print("Generated filename list for hema:", len(hema_mylist), "hema files")
# print("Equal number of files?:", (len(mylist)==len(nb_mylist))==(len(mylist)==len(hema_mylist)))
# Out:
# Read in: 40  files
# Generated filename list for nb: 40 nb files
# Equal number of files?: True

# %% [markdown]
# 747384 - cannot locate

# %%
i
# Out:
# 18

# %%
mylist = mylist[19:]
nb_mylist = nb_mylist[19:]

# %% [markdown]
# Process new files to make predictions

# %%
n_total = len(mylist)
faulty_file = []
for i in range(0,n_total):
    
    # Read in unlabelled/unannotated file
    print("FILE", mylist[i], "Number: ", i+1,"/",n_total)
    print("---------------STEP1: DATA FILE-------------------")
    dat_file = mylist[i]
    
    dat_orig = pd.read_csv('C:/Users/mokur/OneDrive - University of Cambridge/Attachments/Jan2023/Cell_pipeline/detection_stardist/'+dat_file,sep="\t")
    dat_orig.columns.values[5] = "Centroid_X"
    dat_orig.columns.values[6] = "Centroid_Y"
    dat_ = dat_orig[cell_extracted_features]
    dab_df = dat_orig[dab_features]
    dat = dat_.copy()
    dat.loc[:,'Class'] = dat.shape[0]*['Unlabelled']
    print("Read in data file:", dat_file)
    print("Data shape is:", dat.shape)
    print("----------------------------------------------------------------------------")
    
    # Importing NB cells
    print("---------------STEP2: NB FILE-------------------")
    nb_dat_file = nb_mylist[i]
    nb_dat_ = pd.read_csv('E:/number_of_neighbours/'+nb_dat_file,sep=",")
    nb_dat_ = nb_dat_.rename(columns={'X':'Centroid_X','Y':'Centroid_Y'})
    nb_dat = nb_dat_[nnb_extracted_features]
    
    print("Read in nb file:", nb_dat_file)
    print("nb_dat shape is:", nb_dat.shape)
    print("-----------------------------------------")
    
    ## Merge NB info to main data ***** From now on: Use 'combined'
    combined = dat.merge(nb_dat.drop_duplicates(),on=['Centroid_X','Centroid_Y'],how='inner',validate='1:1')
    print("Successfully combine nb cell counts to main data")
    print('Expected & Observed row matched?: ', dat.shape[0]==combined.shape[0])
    print('Expected & Observed columns matched?: ', (dat.shape[1]+nb_dat.shape[1]-2)==combined.shape[1])
    print("----------------------------------------------------------------------------")
    

    # Importing hema files 
    print("---------------STEP3: HEMA FILE-------------------")
    hema_dat = dat[['Centroid_X','Centroid_Y','Hematoxylin: Nucleus: Mean']]
    print("hema_dat shape is:", hema_dat.shape)
    print("----------------------------------------------------------------------------")
    
    ############################  Normalising hema files ############################ 
    print("---------------STEP4: HEMA NORM-------------------")
    
    # 1) Find cells need removing 
    hema_to_remove = find_hema_to_remove_slide(hema_dat)
    print("No. of cells with normalised Hema >1:",
          len(hema_to_remove),
            "from", len(hema_dat),"detected cells")

    # 2) Remove hema from the slides 
    retained, removed_, remove_log = remove_cell_hema_slide(combined,
                           hema_to_remove)
    
    print(dat_file,":",
           'To be removed = actually removed?',remove_log,
           ' &',removed_.shape[0],"cells removed")
    
    # label those cells we have removed as having Class = 'Excluded'
    removed = removed_.copy()
    removed.loc[:,'Class'] = ['Excluded']*removed.shape[0]

    print("----------------------------------------------------------------------------")

    ############################ Checking for NAs & Other bits  
    print("---------------STEP5: CHECKING NA & REGIONS-------------------")
    
    # 1) Selecting only GREY MATTER PORTION (since thresholding won't make sense in WM)
    if (retained[retained['Name']=='Grey_matter'].shape[0] == 0): 
        faulty_file.append(retained['Image'][0])
        continue  
    
    retained2 = retained[retained['Name']=='Grey_matter']  # only has GM now
    retained_not_GM = retained[retained['Name']!='Grey_matter'] # Class will be Unlabelled
    

    # 2) Remove NA cells 
    retained3 = retained2.dropna()
    NA_proportion = retained2[retained2.isna().any(axis=1)]
    print("Shape of data, ready for prediction", retained3.shape)


    print("----------------------------------------------------------------------------")
 
    ############################ Prediction
    print("---------------STEP7: PREDICTIONS-------------------")
    
    # Create new variable for retained to add Class predictions to
    retained_final = retained3.copy()

    # Dropping extra info features 
    X_unlabelled = retained3.drop(columns=['Image',
                                           'Name',
                                           'Class',
                                           'Parent',
                                           'ROI',
                                           'Centroid_X',
                                           'Centroid_Y'])
    print('X_unlabelled shape: ', X_unlabelled.shape)

        
    # 1) Perform prediction on the novel slide
    model.predict(X_unlabelled)
    retained_final.loc[:,'Class'] = model.prediction
    print(retained_final['Class'].value_counts())
    
    print("----------------------------------------------------------------------------")
    ############################ Extracting data out  ############################ 
    print("---------------STEP8: DATA EXTRACTION & EXPORT-------------------")

    # 1) Combining predicted cells & excluded cells (prior to prediction)
    output_slide = pd.concat([removed, # from hema
                              retained_not_GM, # non GM 
                              NA_proportion, # GM with NA 
                              retained_final]) # predicted GM portion
    
    # 2) Add DAB information 
    output_slide_dab = output_slide.merge(dab_df,on=['Centroid_X','Centroid_Y'])
    
    # 2) Checking input data == output data 
    print("Input data == output data?:", combined.shape[0]==output_slide_dab.shape[0])

    # 3) Checking if there are NA values in predicted portion after combining data 
    pred_complete=output_slide_dab[output_slide_dab['Class']!='Unlabelled'].isna().sum().sum()
    print("No NAN values in predicted portion?: ", 0==pred_complete)
    
    # 4) Exporting relevant information 
    path = 'C:/Users/mokur/OneDrive/Desktop/Digital_path/Cell_pipeline/Predictions/Occipital/' + output_slide_dab.iloc[0,0]+'_predictions.txt'
    output_slide_dab.to_csv(path, sep='\t',index=False)
    print("Exported prediction of : ",dat_file)
    print("----------------------------------------------------------------------------")

print("**********ALL DONE! YAY, no error!***********")
# Out:
# FILE 747380_all.txt Number:  1 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747380_all.txt
# Data shape is: (288176, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747380_all_neighbours.csv
# nb_dat shape is: (288176, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (288176, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2882 from 288176 detected cells
# 747380_all.txt : To be removed = actually removed? True  & 2882 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (218281, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (218281, 44)
# Others       90674
# Neuron       54767
# Oligo        27071
# Astro        25823
# Ambiguous    19946
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747380_all.txt
# ----------------------------------------------------------------------------
# FILE 747856_all.txt Number:  2 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747856_all.txt
# Data shape is: (294541, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747856_all_neighbours.csv
# nb_dat shape is: (294541, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (294541, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2939 from 294541 detected cells
# 747856_all.txt : To be removed = actually removed? True  & 2939 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (190255, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (190255, 44)
# Others       64232
# Neuron       47704
# Oligo        32329
# Astro        29895
# Ambiguous    16095
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747856_all.txt
# ----------------------------------------------------------------------------
# FILE 747850_all.txt Number:  3 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747850_all.txt
# Data shape is: (645719, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747850_all_neighbours.csv
# nb_dat shape is: (645719, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (645719, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6446 from 645719 detected cells
# 747850_all.txt : To be removed = actually removed? True  & 6446 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (383267, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (383267, 44)
# Others       138517
# Neuron       105255
# Oligo         66520
# Astro         37969
# Ambiguous     35006
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747850_all.txt
# ----------------------------------------------------------------------------
# FILE 703521_all.txt Number:  4 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 703521_all.txt
# Data shape is: (319118, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 703521_all_neighbours.csv
# nb_dat shape is: (319118, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (319118, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 3192 from 319118 detected cells
# 703521_all.txt : To be removed = actually removed? True  & 3192 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (240868, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (240868, 44)
# Others       108547
# Neuron        56649
# Oligo         33077
# Astro         22683
# Ambiguous     19912
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  703521_all.txt
# ----------------------------------------------------------------------------
# FILE 747378_all.txt Number:  5 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747378_all.txt
# Data shape is: (280266, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747378_all_neighbours.csv
# nb_dat shape is: (280266, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (280266, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2797 from 280266 detected cells
# 747378_all.txt : To be removed = actually removed? True  & 2797 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (224663, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (224663, 44)
# Others       105064
# Neuron        48120
# Oligo         30313
# Astro         21516
# Ambiguous     19650
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747378_all.txt
# ----------------------------------------------------------------------------
# FILE 747377_all.txt Number:  6 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747377_all.txt
# Data shape is: (232377, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747377_all_neighbours.csv
# nb_dat shape is: (232377, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (232377, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2324 from 232377 detected cells
# 747377_all.txt : To be removed = actually removed? True  & 2324 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (164951, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (164951, 44)
# Others       53468
# Astro        37359
# Neuron       31536
# Oligo        28772
# Ambiguous    13816
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747377_all.txt
# ----------------------------------------------------------------------------
# FILE 747386_all.txt Number:  7 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747386_all.txt
# Data shape is: (543991, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747386_all_neighbours.csv
# nb_dat shape is: (543991, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (543991, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 5438 from 543991 detected cells
# 747386_all.txt : To be removed = actually removed? True  & 5438 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (330178, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (330178, 44)
# Neuron       87484
# Others       80552
# Astro        76108
# Oligo        58868
# Ambiguous    27166
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747386_all.txt
# ----------------------------------------------------------------------------
# FILE 747376_all.txt Number:  8 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747376_all.txt
# Data shape is: (314918, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747376_all_neighbours.csv
# nb_dat shape is: (314918, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (314918, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 3141 from 314918 detected cells
# 747376_all.txt : To be removed = actually removed? True  & 3141 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (233943, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (233943, 44)
# Others       68341
# Astro        57534
# Neuron       56263
# Oligo        32591
# Ambiguous    19214
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747376_all.txt
# ----------------------------------------------------------------------------
# FILE 747385_all.txt Number:  9 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747385_all.txt
# Data shape is: (399355, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747385_all_neighbours.csv
# nb_dat shape is: (399355, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (399355, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 3986 from 399355 detected cells
# 747385_all.txt : To be removed = actually removed? True  & 3986 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (271802, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (271802, 44)
# Others       78789
# Neuron       71731
# Astro        62151
# Oligo        37660
# Ambiguous    21471
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747385_all.txt
# ----------------------------------------------------------------------------
# FILE 747375_all.txt Number:  10 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747375_all.txt
# Data shape is: (236091, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747375_all_neighbours.csv
# nb_dat shape is: (236091, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (236091, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2360 from 236091 detected cells
# 747375_all.txt : To be removed = actually removed? True  & 2360 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (183025, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (183025, 44)
# Others       74087
# Neuron       35274
# Astro        30949
# Oligo        25303
# Ambiguous    17412
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747375_all.txt
# ----------------------------------------------------------------------------
# FILE 747374_all.txt Number:  11 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747374_all.txt
# Data shape is: (263921, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747374_all_neighbours.csv
# nb_dat shape is: (263921, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (263921, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2636 from 263921 detected cells
# 747374_all.txt : To be removed = actually removed? True  & 2636 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (188414, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (188414, 44)
# Others       64511
# Neuron       42151
# Astro        37961
# Oligo        28964
# Ambiguous    14827
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747374_all.txt
# ----------------------------------------------------------------------------
# FILE 747849_all.txt Number:  12 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747849_all.txt
# Data shape is: (254422, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747849_all_neighbours.csv
# nb_dat shape is: (254422, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (254422, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2539 from 254422 detected cells
# 747849_all.txt : To be removed = actually removed? True  & 2539 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (181225, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (181225, 44)
# Others       61893
# Neuron       40280
# Oligo        35891
# Astro        27086
# Ambiguous    16075
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747849_all.txt
# ----------------------------------------------------------------------------
# FILE 747372_all.txt Number:  13 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747372_all.txt
# Data shape is: (307372, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747372_all_neighbours.csv
# nb_dat shape is: (307372, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (307372, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 3065 from 307372 detected cells
# 747372_all.txt : To be removed = actually removed? True  & 3065 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (206676, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (206676, 44)
# Others       52817
# Astro        52277
# Neuron       44030
# Oligo        40092
# Ambiguous    17460
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747372_all.txt
# ----------------------------------------------------------------------------
# FILE 747371_all.txt Number:  14 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747371_all.txt
# Data shape is: (238446, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747371_all_neighbours.csv
# nb_dat shape is: (238446, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (238446, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2384 from 238446 detected cells
# 747371_all.txt : To be removed = actually removed? True  & 2384 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (173101, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (173101, 44)
# Others       45857
# Neuron       39580
# Oligo        37659
# Astro        36293
# Ambiguous    13712
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747371_all.txt
# ----------------------------------------------------------------------------
# FILE 747390_all.txt Number:  15 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747390_all.txt
# Data shape is: (211145, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747390_all_neighbours.csv
# nb_dat shape is: (211145, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (211145, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 2106 from 211145 detected cells
# 747390_all.txt : To be removed = actually removed? True  & 2106 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (121970, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (121970, 44)
# Others       64698
# Neuron       16531
# Astro        16328
# Ambiguous    14036
# Oligo        10377
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747390_all.txt
# ----------------------------------------------------------------------------
# FILE 760054_all.txt Number:  16 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 760054_all.txt
# Data shape is: (378328, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 760054_all_neighbours.csv
# nb_dat shape is: (378328, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (378328, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 3782 from 378328 detected cells
# 760054_all.txt : To be removed = actually removed? True  & 3782 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (249991, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (249991, 44)
# Others       137820
# Neuron        40847
# Ambiguous     29859
# Astro         21098
# Oligo         20367
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  760054_all.txt
# ----------------------------------------------------------------------------
# FILE 747855_all.txt Number:  17 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747855_all.txt
# Data shape is: (660161, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747855_all_neighbours.csv
# nb_dat shape is: (660161, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (660161, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 6599 from 660161 detected cells
# 747855_all.txt : To be removed = actually removed? True  & 6599 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (386039, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (386039, 44)
# Others       123751
# Neuron        93342
# Astro         74398
# Oligo         60940
# Ambiguous     33608
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  747855_all.txt
# ----------------------------------------------------------------------------
# FILE 747854_all.txt Number:  18 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747854_all.txt
# Data shape is: (420970, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747854_all_neighbours.csv
# nb_dat shape is: (420970, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (420970, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 4206 from 420970 detected cells
# 747854_all.txt : To be removed = actually removed? True  & 4206 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (272608, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (272608, 44)
# Others       90816
# Neuron       60472
# Oligo        50190
# Astro        48497
# Ambiguous    22633
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747854_all.txt
# ----------------------------------------------------------------------------
# FILE 747853_all.txt Number:  19 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 747853_all.txt
# Data shape is: (582222, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 747853_all_neighbours.csv
# nb_dat shape is: (582222, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (582222, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 5821 from 582222 detected cells
# 747853_all.txt : To be removed = actually removed? True  & 5821 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (351472, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (351472, 44)
# Others       111765
# Oligo         77744
# Neuron        70808
# Astro         63694
# Ambiguous     27461
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  747853_all.txt
# ----------------------------------------------------------------------------
# FILE 772018_all.txt Number:  20 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 772018_all.txt
# Data shape is: (501334, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 772018_all_neighbours.csv
# nb_dat shape is: (501334, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (501334, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 5011 from 501334 detected cells
# 772018_all.txt : To be removed = actually removed? True  & 5011 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (376578, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (376578, 44)
# Others       132911
# Neuron        95951
# Astro         58994
# Oligo         52282
# Ambiguous     36440
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  True
# Exported prediction of :  772018_all.txt
# ----------------------------------------------------------------------------
# FILE 771897_all.txt Number:  21 / 21
# ---------------STEP1: DATA FILE-------------------
# Read in data file: 771897_all.txt
# Data shape is: (571597, 41)
# ----------------------------------------------------------------------------
# ---------------STEP2: NB FILE-------------------
# Read in nb file: 771897_all_neighbours.csv
# nb_dat shape is: (571597, 12)
# -----------------------------------------
# Successfully combine nb cell counts to main data
# Expected & Observed row matched?:  True
# Expected & Observed columns matched?:  True
# ----------------------------------------------------------------------------
# ---------------STEP3: HEMA FILE-------------------
# hema_dat shape is: (571597, 3)
# ----------------------------------------------------------------------------
# ---------------STEP4: HEMA NORM-------------------
# No. of cells with normalised Hema >1: 5714 from 571597 detected cells
# 771897_all.txt : To be removed = actually removed? True  & 5714 cells removed
# ----------------------------------------------------------------------------
# ---------------STEP5: CHECKING NA & REGIONS-------------------
# Shape of data, ready for prediction (408623, 51)
# ----------------------------------------------------------------------------
# ---------------STEP7: PREDICTIONS-------------------
# X_unlabelled shape:  (408623, 44)
# Others       157117
# Neuron       104511
# Astro         67034
# Oligo         45329
# Ambiguous     34632
# Name: Class, dtype: int64
# ----------------------------------------------------------------------------
# ---------------STEP8: DATA EXTRACTION & EXPORT-------------------
# Input data == output data?: True
# No NAN values in predicted portion?:  False
# Exported prediction of :  771897_all.txt
# ----------------------------------------------------------------------------
# **********ALL DONE! YAY, no error!***********
